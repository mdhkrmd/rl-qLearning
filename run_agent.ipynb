# %%
# %%time
# !python run_agent.py
# Out:
# The shortest route: 40CPU times: total: 625 ms
# Wall time: 8min 56s
# F:\Computer Science\Python\AI Mastery - Orbit\AI Domain - Reinforcement Learning\6. Ujian Praktik\agent_brain.py:73: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.q_table = self.q_table.append(
# F:\Computer Science\Python\AI Mastery - Orbit\AI Domain - Reinforcement Learning\6. Ujian Praktik\agent_brain.py:73: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.q_table = self.q_table.append(
# F:\Computer Science\Python\AI Mastery - Orbit\AI Domain - Reinforcement Learning\6. Ujian Praktik\agent_brain.py:73: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.q_table = self.q_table.append(
# ...
